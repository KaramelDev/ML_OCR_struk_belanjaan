# %%
from sentence_transformers import SentenceTransformer, util
model = SentenceTransformer('sentence-transformers/LaBSE')
produk_pusat = [
    "nivea men cream 30ml",
    "lifebuoy sabun cair 250ml",
    "sunlight lemon jeruk nipis 200ml",
]

vektor_pusat = model.encode(produk_pusat, convert_to_tensor=True)
produk_struk = [
    "nv mn 30ml",
    "lifeboy sabun",
    "sunligt jeruk"
]

for item in produk_struk:
    vektor_item = model.encode(item, convert_to_tensor=True)
    similarity = util.cos_sim(vektor_item, vektor_pusat)

    idx_best = similarity.argmax()
    print(f"{item} → {produk_pusat[idx_best]} (skor: {similarity[0][idx_best]:.4f})")

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("BAAI/bge-small-en-v1.5")

produk_pusat = [
    "nivea men cream 30ml",
    "lifebuoy sabun cair 250ml",
    "sunlight lemon jeruk nipis 200ml",
]

vektor_pusat = model.encode(produk_pusat, convert_to_tensor=True)

produk_struk = [
    "nv mn 30ml",
    "lifeboy sabun",
    "sunligt jeruk"
]

for item in produk_struk:
    vektor_item = model.encode(item, convert_to_tensor=True)
    similarity = util.cos_sim(vektor_item, vektor_pusat)

    idx_terdekat = similarity.argmax()
    print(f"{item} ➜ {produk_pusat[idx_terdekat]} (skor: {similarity[0][idx_terdekat]:.4f})")

# %%
from sentence_transformers import SentenceTransformer, util
import pandas as pd

model = SentenceTransformer("BAAI/bge-small-en-v1.5")
produk_pusat = pd.read_excel('SKUNivea.xlsx',sheet_name='All NIVEA PL Mei 2024', skiprows=2,usecols=range(9)  )
produk_pusat = produk_pusat["Description"].astype(str).str.lower().tolist()

produk_struk = [
    "nv mn 30ml",        
    "nvea lotion white"  
]

vektor_pusat = model.encode(produk_pusat, convert_to_tensor=True)

for item in produk_struk:
    vektor_item = model.encode(item, convert_to_tensor=True)
    similarity = util.cos_sim(vektor_item, vektor_pusat)

    idx_best = similarity.argmax()
    print(f"{item} ➜ {produk_pusat[idx_best]} (skor: {similarity[0][idx_best]:.4f})")

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("all-MiniLM-L6-v2")
produk_pusat = [
    "nivea men cream 30ml",
    "nivea face wash 100ml",
    "nivea lip balm cherry 4.8g",
    "nivea body lotion extra white 200ml",
    "nivea deo roll on black & white 50ml",
    "lifebuoy sabun cair 250ml",
    "sunlight lemon 200ml",
    "pepsodent pasta gigi 190g",
    "dove shampoo 170ml",
    "rinso detergen bubuk 800g"
]

produk_struk = [
    "nv mn 30ml",     
    "nvea lotion white" 
]

vektor_pusat = model.encode(produk_pusat, convert_to_tensor=True)

for item in produk_struk:
    vektor_item = model.encode(item, convert_to_tensor=True)
    similarity = util.cos_sim(vektor_item, vektor_pusat)

    idx_best = similarity.argmax()
    print(f"{item} ➜ {produk_pusat[idx_best]} (skor: {similarity[0][idx_best]:.4f})")

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("thenlper/gte-small")
produk_pusat = [
    "nivea men cream 30ml",
    "nivea face wash 100ml",
    "nivea lip balm cherry 4.8g",
    "nivea body lotion extra white 200ml",
    "nivea deo roll on black & white 50ml",
    "lifebuoy sabun cair 250ml",
    "sunlight lemon 200ml",
    "pepsodent pasta gigi 190g",
    "dove shampoo 170ml",
    "rinso detergen bubuk 800g"
]

produk_struk = [
    "nv mn 30ml",       
    "nvea lotion white"    
]
vektor_pusat = model.encode(produk_pusat, convert_to_tensor=True)

for item in produk_struk:
    vektor_item = model.encode(item, convert_to_tensor=True)
    similarity = util.cos_sim(vektor_item, vektor_pusat)

    idx_terdekat = similarity.argmax()
    print(f"{item} ➜ {produk_pusat[idx_terdekat]} (skor: {similarity[0][idx_terdekat]:.4f})")

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("sentence-transformers/all-mpnet-base-v2")
produk_pusat = [
    "nivea men cream 30ml",
    "lifebuoy sabun cair 250ml",
    "sunlight lemon 200ml",
    "pepsodent pasta gigi 190g",
    "dove shampoo 170ml",
    "rinso detergen bubuk 800g",
    "clear men shampoo 170ml",
    "so klin pewangi pakaian",
    "molto pewangi konsentrat",
    "sunsilk black shine 170ml"
]
produk_struk = [
    "nv mn 30ml",     
    "sunligt jeruk"   
]
vektor_pusat = model.encode(produk_pusat, convert_to_tensor=True)

for item in produk_struk:
    vektor_item = model.encode(item, convert_to_tensor=True)
    similarity = util.cos_sim(vektor_item, vektor_pusat)

    idx_best = similarity.argmax()
    print(f"{item} ➜ {produk_pusat[idx_best]} (skor: {similarity[0][idx_best]:.4f})")

# %%
from sentence_transformers import SentenceTransformer, util

model = SentenceTransformer("distilbert-base-nli-stsb-mean-tokens")

vektor_pusat = model.encode(produk_pusat, convert_to_tensor=True)

for item in produk_struk:
    vektor_item = model.encode(item, convert_to_tensor=True)
    similarity = util.cos_sim(vektor_item, vektor_pusat)

    idx_best = similarity.argmax()
    print(f"{item} ➜ {produk_pusat[idx_best]} (skor: {similarity[0][idx_best]:.4f})")

# %%
import cv2
from PIL import Image
import pytesseract

cv_img = cv2.imread("struk.jpg")
gray = cv2.cvtColor(cv_img, cv2.COLOR_BGR2GRAY)
thresh = cv2.threshold(gray, 150, 255, cv2.THRESH_BINARY_INV)[1]

pil_img = Image.fromarray(thresh)
pytesseract.pytesseract.tesseract_cmd = r"D:\ocr\tesseract.exe"

text = pytesseract.image_to_string(pil_img)
print(text
)

# %%
import pandas as pd
import psycopg2
from io import StringIO

# koneksi psycopg2
conn = psycopg2.connect(
    dbname="strukAI",
    user="postgres",
    password="bairn1021",
    host="localhost",
    port="5432"
)

df = pd.read_excel('SKUNivea.xlsx', usecols=range(9),skiprows=2,sheet_name='All NIVEA PL Mei 2024')
df = df.dropna()
float_cols = df.select_dtypes(include=['float']).columns

# Bulatkan dan konversi ke int (jika tidak ada NaN)
df[float_cols] = df[float_cols].round().astype('int64')
# ---- 1) Konversi DataFrame → CSV (tanpa header & index) di memori
buffer = StringIO()
df.to_csv(buffer, index=False, header=False)
buffer.seek(0)

# ---- 2) COPY ke tabel
cursor = conn.cursor()
try:
    cursor.copy_from(
        file=buffer,
        table="data_pusat",
        sep=",",
        null="",
        columns=list(df.columns)   # urutkan kolom
    )
    conn.commit()
except Exception as e:
    conn.rollback()
    raise e
finally:
    cursor.close()
    conn.close()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 127 entries, 1 to 127
# Data columns (total 9 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Brand                                 127 non-null    object
#  1   Sub Brand AS                          127 non-null    object
#  2   Brand Group AS                        127 non-null    object
#  3   Description                           127 non-null    object
#  4   Barcode (Pieces)                      127 non-null    float64
#  5   Harga PTT/Sebelum PPN                 127 non-null    float64
#  6   Kuantiti per Karton/Dus               127 non-null    float64
#  7   Harga PPN                             127 non-null    float64
#  8   Harga Jual ke Konsumen yg Disarankan  127 non-null    float64
# dtypes: float64(5), object(4)
# memory usage: 9.9+ KB

# %%
df['Barcode (Pieces)'] = df['Barcode (Pieces)'].round().astype('int64')

# %%
df
# Out:
#      Brand  Sub Brand AS  Brand Group AS  \
# 1    Nivea     Nivea Men  NM Moisturiser
# 2    Nivea     Nivea Men  NM Moisturiser
# 3    Nivea     Nivea Men    NM Cleansing
# 4    Nivea     Nivea Men    NM Cleansing
# 5    Nivea     Nivea Men    NM Cleansing
# ..     ...           ...             ...
# 123  Nivea     Nivea Sun             Sun
# 124  Nivea     Nivea Sun             Sun
# 125  Nivea     Nivea Sun             Sun
# 126  Nivea  NLC Lip Care        Lip Care
# 127  Nivea  NLC Lip Care        Lip Care
#
#                                            Description  Barcode (Pieces)  \
# 1                             NIVEA MEN Creme Tin 30ml          40061191
# 2                             NIVEA MEN Creme Tin 75ml     8999777012373
# 3    NIVEA MEN Extra Bright Dark Spot Minimizer Fac...     8999777888350
# 4    NIVEA MEN Extra Bright Dark Spot Minimizer Fac...     8999777888367
# 5    NIVEA MEN Bright Oil Clear Anti Shine + Purify...     8999777002602
# ...

# %%
import pandas as pd
import psycopg2

# Koneksi psycopg2
conn = psycopg2.connect(
    dbname="strukAI",
    user="postgres",
    password="bairn1021",
    host="localhost",
    port="5432"
)

# Ambil data
query = "SELECT * FROM data_pusat"
df = pd.read_sql_query(query, conn)

# Tutup koneksi
conn.close()
# Out:
# C:\Users\naeko\AppData\Local\Temp\ipykernel_612\3736186404.py:15: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127 entries, 0 to 126
# Data columns (total 10 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   id                                    127 non-null    int64
#  1   Brand                                 127 non-null    object
#  2   Sub Brand AS                          127 non-null    object
#  3   Brand Group AS                        127 non-null    object
#  4   Description                           127 non-null    object
#  5   Barcode (Pieces)                      127 non-null    float64
#  6   Harga PTT/Sebelum PPN                 127 non-null    int64
#  7   Kuantiti per Karton/Dus               127 non-null    int64
#  8   Harga PPN                             127 non-null    int64
#  9   Harga Jual ke Konsumen yg Disarankan  127 non-null    int64
# dtypes: float64(1), int64(5), object(4)
# memory usage: 10.1+ KB

# %%
df
# Out:
#       id  Brand  Sub Brand AS  Brand Group AS  \
# 0      1  Nivea     Nivea Men  NM Moisturiser
# 1      2  Nivea     Nivea Men  NM Moisturiser
# 2      3  Nivea     Nivea Men    NM Cleansing
# 3      4  Nivea     Nivea Men    NM Cleansing
# 4      5  Nivea     Nivea Men    NM Cleansing
# ..   ...    ...           ...             ...
# 122  123  Nivea     Nivea Sun             Sun
# 123  124  Nivea     Nivea Sun             Sun
# 124  125  Nivea     Nivea Sun             Sun
# 125  126  Nivea  NLC Lip Care        Lip Care
# 126  127  Nivea  NLC Lip Care        Lip Care
#
#                                            Description  Barcode (Pieces)  \
# 0                             NIVEA MEN Creme Tin 30ml      4.006119e+07
# 1                             NIVEA MEN Creme Tin 75ml      8.999777e+12
# 2    NIVEA MEN Extra Bright Dark Spot Minimizer Fac...      8.999778e+12
# 3    NIVEA MEN Extra Bright Dark Spot Minimizer Fac...      8.999778e+12
# ...

# %%
import easyocr

reader = easyocr.Reader(['en'])
result = reader.readtext('sample/Receipt NIVEA/ini.jpg')
print(result)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ...
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# d:\pkl\venv_py39\lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# ...

# %%
import easyocr
from PIL import Image
import re
import json

reader = easyocr.Reader(['id'], gpu=False)

def OCR_EasyOCR(image_path):
    results = reader.readtext(image_path, detail=0)
    lines = [line.strip().lower() for line in results]
    
    ocr_json = {
        "invoice_number": None,
        "phone": None,
        "alamat": None,
        "email": None,
        "nama_toko": None,
        "tanggal": None,
        "daftar_barang": [],
        "total_belanja": None
    }

    for line in lines:
        if re.search(r"\d{2}/\d{2}/\d{4}", line):
            ocr_json["tanggal"] = re.search(r"\d{2}/\d{2}/\d{4}", line).group()
        if "@" in line:
            ocr_json["email"] = line
        if any(word in line for word in ["jalan", "jl.", "alamat"]):
            ocr_json["alamat"] = line
        if re.search(r"(telp|hp|phone|wa)", line):
            ocr_json["phone"] = re.sub(r"\D", "", line)
        if ocr_json["nama_toko"] is None and len(line) > 4:
            ocr_json["nama_toko"] = line

    for line in lines:
        if "total" in line:
            angka = re.findall(r"\d+[.,]?\d*", line)
            if angka:
                try:
                    ocr_json["total_belanja"] = float(angka[-1].replace(",", "").replace(".", ""))
                except:
                    pass

    for line in lines:
        if any(char.isdigit() for char in line) and any(c.isalpha() for c in line):
            tokens = line.split()
            if len(tokens) >= 2:
                nama = " ".join(tokens[:-1])
                try:
                    harga = float(tokens[-1].replace(",", "").replace(".", ""))
                except:
                    harga = 0.0
                ocr_json["daftar_barang"].append({
                    "nama": nama,
                    "qty": 1,
                    "harga_satuan": harga,
                    "subtotal": harga
                })

    return ocr_json

if __name__ == "__main__":
    image_path = "sample/Receipt NIVEA/ini.jpg"
    hasil = OCR_EasyOCR(image_path)
    print(json.dumps(hasil, indent=2, ensure_ascii=False))
# Out:
# Using CPU. Note: This module is much faster with a GPU.
# d:\pkl\venv_py39\lib\site-packages\torch\utils\data\dataloader.py:665: UserWarning: 'pin_memory' argument is set as true but no accelerator is found, then device pinned memory won't be used.
#   warnings.warn(warn_msg)
# {
#   "invoice_number": null,
#   "phone": "",
#   "alamat": "jl.",
#   "email": "total @ty",
#   "nama_toko": "tok & jerry shalayan",
#   "tanggal": null,
#   "daftar_barang": [
#     {
#       "nama": "trunojoyo mo, 41",
#       "qty": 1,
#       "harga_satuan": 0.0,
#       "subtotal": 0.0
#     },
#     {
#       "nama": "03-01-2022 11,59",
#       "qty": 1,
#       "harga_satuan": 0.0,
#       "subtotal": 0.0
#     },
#     {
#       "nama": "lilin 483",
#       "qty": 1,
#       "harga_satuan": 0.0,
#       "subtotal": 0.0
#     },
#     {
#       "nama": "8",
#       "qty": 1,
#       "harga_satuan": 0.0,
#       "subtotal": 0.0
#     },
#     {
#       "nama": "1.00",
#       "qty": 1,
# ...

# %%
import pytesseract
from PIL import Image
import re
import json

# Pastikan path pytesseract sudah sesuai jika belum otomatis
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def OCR_Pytesseract(image_path):
    img = Image.open(image_path)
    text = pytesseract.image_to_string(img, lang='eng')

    lines = text.split('\n')
    lines = [line.strip().lower() for line in lines if line.strip()]

    ocr_json = {
        "invoice_number": None,
        "phone": None,
        "alamat": None,
        "email": None,
        "nama_toko": None,
        "tanggal": None,
        "daftar_barang": [],
        "total_belanja": None
    }

    # Ekstrak informasi dasar
    for line in lines:
        if re.search(r'\d{2}/\d{2}/\d{4}', line):
            ocr_json["tanggal"] = re.search(r'\d{2}/\d{2}/\d{4}', line).group()
        if '@' in line:
            ocr_json["email"] = line
        if any(x in line for x in ["jalan", "jl.", "alamat"]):
            ocr_json["alamat"] = line
        if re.search(r'(telp|phone|wa|hp)', line):
            number = re.sub(r'\D', '', line)
            if len(number) >= 8:
                ocr_json["phone"] = number
        if ocr_json["nama_toko"] is None and len(line) > 3:
            ocr_json["nama_toko"] = line

    # Total belanja
    for line in lines:
        if 'total' in line:
            angka = re.findall(r'\d+[.,]?\d*', line)
            if angka:
                try:
                    ocr_json["total_belanja"] = float(angka[-1].replace(',', '').replace('.', ''))
                except:
                    pass

    # Deteksi daftar barang (sederhana)
    for line in lines:
        tokens = line.split()
        if len(tokens) >= 2 and any(c.isdigit() for c in tokens[-1]):
            nama = ' '.join(tokens[:-1])
            try:
                harga = float(tokens[-1].replace(',', '').replace('.', ''))
            except:
                harga = 0.0
            ocr_json["daftar_barang"].append({
                "nama": nama,
                "qty": 1,
                "harga_satuan": harga,
                "subtotal": harga
            })

    return ocr_json


# ==== Contoh Penggunaan ====
if __name__ == "__main__":
    image_path = "sample/Receipt NIVEA/ini.jpg"
    hasil = OCR_Pytesseract(image_path)
    print(json.dumps(hasil, indent=2, ensure_ascii=False))
# Out:
# {
#   "invoice_number": null,
#   "phone": "313091449",
#   "alamat": "jl. trunojoyo no. 44 bangkalan",
#   "email": "lilin 493 ist @ pliar",
#   "nama_toko": "tok & jerry swalay am",
#   "tanggal": null,
#   "daftar_barang": [
#     {
#       "nama": "telp. (o31",
#       "qty": 1,
#       "harga_satuan": 0.0,
#       "subtotal": 0.0
#     },
#     {
#       "nama": "1.00 pcs 9,000 =",
#       "qty": 1,
#       "harga_satuan": 9000.0,
#       "subtotal": 9000.0
#     },
#     {
#       "nama": "2.00 pcs 14,000 =",
#       "qty": 1,
#       "harga_satuan": 26000.0,
#       "subtotal": 26000.0
#     },
#     {
#       "nama": "1.00 pcs 15,750 =",
#       "qty": 1,
#       "harga_satuan": 15750.0,
#       "subtotal": 15750.0
#     },
#     {
#       "nama": "1,00 p&s 10,300 =",
#       "qty": 1,
#       "harga_satuan": 10300.0,
#       "subtotal": 10300.0
#     },
#     {
#       "nama": "1.00 pcs 16,000 =",
#       "qty": 1,
#       "harga_satuan": 16000.0,
# ...

# %%
import pytesseract
from PIL import Image
import google.generativeai as genai
import json

# Konfigurasi Gemini API
genai.configure(api_key="AIzaSyCG8IGd5lgD4m2UocqUGOyGtyd0jM6O4vU")
model_gemini = genai.GenerativeModel("gemini-2.5-flash")

# Pastikan path tesseract
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

def ocr_pytesseract(image_path):
    img = Image.open(image_path)
    text = pytesseract.image_to_string(img, lang='eng')
    return text

def parse_with_gemini(ocr_text):
    prompt = f"""
    Berikut ini adalah hasil OCR dari sebuah struk belanja:

    {ocr_text}

    Tolong ekstrak informasinya dalam format JSON dengan field:
    - invoice_number (string)
    - phone (string)
    - alamat (string)
    - email (string)
    - nama_toko (string)
    - tanggal (string, format DD/MM/YYYY)
    - daftar_barang (array of objects: nama, qty, harga_satuan, subtotal)
    - total_belanja (number)
    Jika ada informasi yang tidak jelas, isi dengan null.
    Hanya berikan JSON saja tanpa penjelasan atau markdown formatting.
    """.strip()

    response = model_gemini.generate_content(prompt)
    try:
        cleaned = response.text.strip().strip('```json').strip('```')
        return json.loads(cleaned)
    except Exception as e:
        return {"error": str(e), "raw_response": response.text}


# ===== Contoh Pemakaian =====
if __name__ == "__main__":
    image_path = "sample/Receipt NIVEA/ini.jpg"
    ocr_result = ocr_pytesseract(image_path)
    json_result = parse_with_gemini(ocr_result)

    print(json.dumps(json_result, indent=2, ensure_ascii=False))
# Out:
# {
#   "invoice_number": "466135",
#   "phone": "(031)-3091449",
#   "alamat": "JL. TRUNOJOYO NO. 44 BANGKALAN",
#   "email": null,
#   "nama_toko": "TOK & JERRY SWALAY AM",
#   "tanggal": "03/01/2022",
#   "daftar_barang": [
#     {
#       "nama": "LILIN 493 IST @ PLIAR",
#       "qty": 1.0,
#       "harga_satuan": 9000.0,
#       "subtotal": 9000.0
#     },
#     {
#       "nama": "HAKARIZO H.ENERGY 60GR ALOE YE",
#       "qty": 2.0,
#       "harga_satuan": 14000.0,
#       "subtotal": 28000.0
#     },
#     {
#       "nama": "PUCELLE LA SIGNATURE COL ROSEK",
#       "qty": 1.0,
#       "harga_satuan": 15750.0,
#       "subtotal": 15750.0
#     },
#     {
#       "nama": "PIXY STICK DEO 34GR VIOLET",
#       "qty": 1.0,
#       "harga_satuan": 10300.0,
#       "subtotal": 10300.0
#     },
#     {
#       "nama": "HIVEA RO SOML INVI BLACK & WHI",
#       "qty": 1.0,
#       "harga_satuan": 16000.0,
#       "subtotal": 16000.0
#     }
#   ],
#   "total_belanja": 79050.0
# }

# %%
from PIL import Image
import google.generativeai as genai
import json

# Konfigurasi Gemini API
genai.configure(api_key="AIzaSyCG8IGd5lgD4m2UocqUGOyGtyd0jM6O4vU")
model_gemini = genai.GenerativeModel("gemini-2.5-flash")

def ocr_gemini_pure(image_path):
    img = Image.open(image_path)
    prompt = """
  This is an image of a shopping receipt. Please extract the information in JSON format with the following fields:
- invoice_number (string)
- phone (string)
- address (string)
- email (string)
- store_name (string)
- date (string, format DD/MM/YYYY)
- item_list (array of objects: name, quantity, unit_price, subtotal)
- total_shopping (number)
If any information is unclear, fill it with null.
Please return only the JSON without any explanation or markdown formatting.
    """

    response = model_gemini.generate_content([prompt, img])
    text = response.text

    try:
        cleaned = text.strip().strip('```json').strip('```')
        return json.loads(cleaned)
    except Exception as e:
        return {"error": str(e), "raw_response": text}


# ===== Contoh Pemakaian =====
if __name__ == "__main__":
    image_path = "Receipt NIVEA/indomaret.jpg"
    result = ocr_gemini_pure(image_path)
    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# {
#   "invoice_number": "20.12.21-07:39/2.1.98/TZX2",
#   "phone": "1500 280",
#   "address": "BOULEVARD HIJAU BLOK C NO.2A-2C RT.003/030, PEJUANG, MEDAN SATRIA, BEKASI, 17131",
#   "email": "KONTAK@INDOMARET.CO.ID",
#   "store_name": "Indomaret",
#   "date": "20/12/2021",
#   "item_list": [
#     {
#       "name": "NIVEA MEN INVS FRS50",
#       "quantity": 1,
#       "unit_price": 19500,
#       "subtotal": 19500
#     },
#     {
#       "name": "POP MIE KRI AYM 75G",
#       "quantity": 1,
#       "unit_price": 4900,
#       "subtotal": 4900
#     }
#   ],
#   "total_shopping": 19800
# }

# %%
from PIL import Image
import google.generativeai as genai
import json

# Konfigurasi Gemini API
genai.configure(api_key="AIzaSyCG8IGd5lgD4m2UocqUGOyGtyd0jM6O4vU")
model_gemini = genai.GenerativeModel("gemini-2.5-flash")

def ocr_gemini_pure(image_path):
    img = Image.open(image_path)
    prompt = """
  Ini adalah gambar struk belanja. Tolong ekstrak informasinya dalam format JSON dengan field:
    - invoice_number (string)
    - phone (string)
    - alamat (string)
    - email (string)
    - nama_toko (string)
    - tanggal (string, format DD/MM/YYYY)
    - daftar_barang (array of objects: nama, qty, harga_satuan, subtotal)
    - total_belanja (number)
    Jika ada informasi yang tidak jelas, isi dengan null.
    Hanya kembalikan JSON-nya saja tanpa penjelasan atau markdown formatting.
    """

    response = model_gemini.generate_content([prompt, img])
    text = response.text

    try:
        cleaned = text.strip().strip('```json').strip('```')
        return json.loads(cleaned)
    except Exception as e:
        return {"error": str(e), "raw_response": text}


# ===== Contoh Pemakaian =====
if __name__ == "__main__":
    image_path = "Receipt NIVEA/indomaret.jpg"
    result = ocr_gemini_pure(image_path)
    print(json.dumps(result, indent=2, ensure_ascii=False))
# Out:
# {
#   "invoice_number": "2.1.98/TZX2 926/ASEP /02",
#   "phone": "1500 280",
#   "alamat": "BOULEVARD HIJAU BLOK C NO.2A-2C RT.003/030, PEJUANG, MEDAN SATRIA, BEKASI, 17131",
#   "email": "KONTAK@INDOMARET.CO.ID",
#   "nama_toko": "Indomaret",
#   "tanggal": "20/12/2021",
#   "daftar_barang": [
#     {
#       "nama": "NIVEA MEN INVS FRS50",
#       "qty": 1,
#       "harga_satuan": 19500,
#       "subtotal": 19500
#     },
#     {
#       "nama": "POP MIE KRI AYM 75G",
#       "qty": 1,
#       "harga_satuan": 4900,
#       "subtotal": 4900
#     }
#   ],
#   "total_belanja": 19800
# }

# %%
import requests
import base64

TOGETHER_API_KEY = '1b156b91bd345a52af7fe8beb3e4413c1bd2c7ebeae69c479a2b8f8caa1e9009' 
API_URL = "https://api.together.xyz/v1/chat/completions"

def encode_image(image_path):
    with open(image_path, "rb") as img:
        return base64.b64encode(img.read()).decode('utf-8')

def together_ocr(image_path):
    base64_img = encode_image(image_path)
    
    headers = {
        "Authorization": f"Bearer {TOGETHER_API_KEY}",
        "Content-Type": "application/json"
    }
    
    data = {
        "model": "meta-llama/Llama-Vision-Free",
        "messages": [
            {"role": "user", "content": [
                {"type": "text", "text": "Tolong lakukan OCR pada gambar ini."},
                {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_img}"}}
            ]}
        ]
    }
    
    response = requests.post(API_URL, headers=headers, json=data)
    
    if response.status_code == 200:
        result = response.json()
        return result['choices'][0]['message']['content']
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None


# === Contoh Penggunaan ===
hasil = together_ocr('sample/Receipt NIVEA/ini.jpg')
print("Hasil OCR:\n", hasil)
# Out:
# Hasil OCR:
#  **Receipt OCR Results**
#
# The receipt is written in Indonesian and contains the following information:
#
# **Date and Time**
# * Date: 03-01-2022
# * Time: 11:59
#
# **Store Information**
# * Name: Tom & Jerry Swalayan
# * Address: Jl. Trunojoyo No. 41 Bangkalan
#
# **Items Purchased**
#
# | Item | Quantity | Price |
# | --- | --- | --- |
# | LILIN 483 ISI 8 PIJAR | 1.00 PCS | 9,000 |
# | MAKARIZO H.ENERGY 60GR ALOE VE | 2.00 PCS | 28,000 |
# | PUCELLE LA SIGNATURE COL ROSEM | 1.00 PCS | 15,750 |
# | PIXY STICK DEO 34GR VIOLET | 1.00 PCS | 10,300 |
# | NIVEA RO 50ML INVI BLACK & WHI | 1.00 PCS | 16,000 |
#
# **Total and Payment**
#
# * Total: 79,050
# * Payment: 100,000
# * Change: 20,950
#
# **Note**
# * The receipt is in Indonesian and the OCR results may not be entirely accurate.
# * The receipt is dated March 1, 2022, and the time is 11:59.

# %%
import requests
import base64

TOGETHER_API_KEY = '1b156b91bd345a52af7fe8beb3e4413c1bd2c7ebeae69c479a2b8f8caa1e9009'
API_URL = "https://api.together.xyz/v1/chat/completions"

def encode_image(image_path):
    with open(image_path, "rb") as img:
        return base64.b64encode(img.read()).decode('utf-8')

def ocr_struk_ke_json(image_path):
    base64_img = encode_image(image_path)
    
    headers = {
        "Authorization": f"Bearer {TOGETHER_API_KEY}",
        "Content-Type": "application/json"
    }
    
    prompt_text = """
Ekstrak informasi dari struk belanja ini dan kembalikan dalam format JSON dengan struktur:
{
  "invoice_number": "...",
  "phone": "...",
  "alamat": "...",
  "email": null,
  "nama_toko": "...",
  "tanggal": "...",
  "daftar_barang": [
    {
      "nama": "...",
      "qty": ...,
      "harga_satuan": ...,
      "subtotal": ...
    }
  ],
  "total_belanja": ...
}
Jika data tidak ada di struk, isi dengan null.
"""
    
    data = {
        "model": "meta-llama/Llama-Vision-Free",
        "messages": [
            {"role": "user", "content": [
                {"type": "text", "text": prompt_text},
                {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_img}"}}
            ]}
        ]
    }
    
    response = requests.post(API_URL, headers=headers, json=data)
    
    if response.status_code == 200:
        result = response.json()
        return result['choices'][0]['message']['content']
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None


# === Contoh Pemakaian ===
hasil_json = ocr_struk_ke_json('sample/Receipt NIVEA/ini.jpg')
print("Hasil OCR JSON:\n", hasil_json)
# Out:
# Error: 429
# {
#   "id": "o386jek-57nCBj-95f66fc33d99b599",
#   "error": {
#     "message": "You have reached the rate limit specific to this model meta-llama/Llama-Vision-Free. The maximum rate limit for this model is 3.0 queries and 60000 tokens per minute. This limit differs from the general rate limits published at Together AI rate limits documentation (https://docs.together.ai/docs/rate-limits). For inquiries about increasing your model-specific rate limit, please contact our sales team (https://www.together.ai/forms/contact-sales)",
#     "type": "model_rate_limit",
#     "param": null,
#     "code": null
#   }
# }
# Hasil OCR JSON:
#  None

# %%
import requests
import base64

TOGETHER_API_KEY = '1b156b91bd345a52af7fe8beb3e4413c1bd2c7ebeae69c479a2b8f8caa1e9009'
API_URL = "https://api.together.xyz/v1/chat/completions"

def encode_image(image_path):
    with open(image_path, "rb") as img:
        return base64.b64encode(img.read()).decode('utf-8')

def ocr_struk_ke_json(image_path):
    base64_img = encode_image(image_path)
    
    headers = {
        "Authorization": f"Bearer {TOGETHER_API_KEY}",
        "Content-Type": "application/json"
    }
    
    prompt_text = """
Ekstrak informasi dari struk belanja ini dan kembalikan dalam format JSON dengan struktur:
{
  "invoice_number": "...",
  "phone": "...",
  "alamat": "...",
  "email": null,
  "nama_toko": "...",
  "tanggal": "...",
  "daftar_barang": [
    {
      "nama": "...",
      "qty": ...,
      "harga_satuan": ...,
      "subtotal": ...
    }
  ],
  "total_belanja": ...
}
Jika data tidak ada di struk, isi dengan null.ouput hanya berisi json
"""
    
    data = {
        "model": "meta-llama/Llama-3.3-70B-Instruct-Turbo-Free",
        "messages": [
            {"role": "user", "content": [
                {"type": "text", "text": prompt_text},
                {"type": "image_url", "image_url": {"url": f"data:image/jpeg;base64,{base64_img}"}}
            ]}
        ]
    }
    
    response = requests.post(API_URL, headers=headers, json=data)
    
    if response.status_code == 200:
        result = response.json()
        return result['choices'][0]['message']['content']
    else:
        print(f"Error: {response.status_code}")
        print(response.text)
        return None


# === Contoh Pemakaian ===
hasil_json = ocr_struk_ke_json('sample/Receipt NIVEA/ini.jpg')
print("Hasil OCR JSON:\n", hasil_json)
# Out:
# Error: 400
# {
#   "id": "o386bAY-3NKUce-95f66f10bd9fb4ac",
#   "error": {
#     "message": "Input validation error",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": null
#   }
# }
# Hasil OCR JSON:
#  None
